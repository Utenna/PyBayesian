# %% [markdown]
# # 闯关题 2：
# > 🔈 我们已经对pandas的使用有了基础的了解，包括常用的数据清洗步骤，接下来的两关将考察pandas的使用，本关涉及到简单的数据框内计算，下一关则要求你完成一个基本的数据清洗过程。
#
# ## 🌐背景介绍
# 闯关题所涉及的数据集来源于2019年发表在nature communication上的一篇文章：
#
# Eisenberg, I. W., Bissett, P. G., Zeynep Enkavi, A., Li, J., MacKinnon, D. P., Marsch, L. A., & Poldrack, R. A. (2019). Uncovering the structure of self-regulation through data-driven ontology discovery. Nature Communications, 10(1), Article 1. https://doi.org/10.1038/s41467-019-10301-1
#
# 在这篇文章中，研究者对自我控制相关的范式和问卷进行了系统的总结，同时公开了收集到的数据集。
#
#
#
# ## 🎯题目要求
# 在本题中，我们需要对数据集中的某一列进行反向计分，并计算几个条目的分数总和
# 1. 导入数据，查看需要反向计分的列
# 2. 进行反向计分
# 3. 将几个条目的得分进行相加
#
# 💡 **友情提醒：**
#
# 数据集挂载路径为 '/home/mw/input/84988498/demographic_health.csv'
#
#  👩‍🏫**在遇到困难时可以查看附带的解题思路~**

# %% [markdown]
# ## STEP1：查看需要反向计分的列
#
# 1. 读取 **"EverythingIsEffort"** 列的数据
# 2. 获取该列的取值水平(例如，该列的数据为7,7,8,9...，那么数据的取值水平为7,8,9)
# 3. 将获得的取值水平复制给变量**a1**，并使用`np.sort()` 将其按从大到小进行排序，(例如排序结果为9,8,7)
# 4. 打印排序后变量**a1**的结果，通过 print 函数进行打印
# > 注：请确保a1的变量类型为array，可使用type(a1)进行查看

# %%
#读取数据集
# df_dem = pd.read_csv("...")

# %%
# 提取"EverythingIsEffort"这一列，获得其中独特的元素，并排序，将最后结果储存到a1这个变量中

#a1 = ...
#print(...)

# %% [markdown]
# ## STEP2：查看需要反向计分的列
#
# 1. 读取"EverythingIsEffort"列的数据
# 2. 对这一列中的数值进行重新编码（如：将4重新编码为0，将3重新编码为1，将2重新编码为2，将1重新编码为3，将0重新编码为4） 并生成新的一列 **"EverythingIsEffort_recode"**
#
# 此题可能的方法可参考：https://www.sfu.ca/~mjbrydon/tutorials/BAinPy/05_recode.html

# %%
#在df_dem中新增一列"EverythingIsEffort_recode"，储存重新编码后的结果

#df_dem["EverythingIsEffort_recode"] = ...

# %% [markdown]
# ## STEP3: 计算几列分数的总和
# 1. 提取数据框中的这几列： **"Nervous","Hopeless","RestlessFidgety","Depressed","EverythingIsEffort_recode","Worthless"**
# 2. 计算这几列分数的总和，将结果储存在新的一列中
# 3.  生成一个新的数据集**df_mental_sum**，其中一列是被试编号，命名为 **"worker_id"** ，另一列是分数总和，命名为 **"sum"**
# 4.  **选取** "sum"列的最后10个值，将结果存在**a2**中

# %%
# df_mental_sum = ...
# a2 = ...

# %% [markdown]
# ## STEP4：将结果保存为 csv 文件
# 💡 这一步的代码你无需修改，直接运行即可。

# %%
# 运行这两个cell,生成答案文件；
# 该文件在左侧文件树project工作区下，你可以自行右击下载或者读取查看

a2 = a2.to_list()

answer = pd.DataFrame({"id": ["q1", "q2"],
                        "answer": [a1,a2]})

answer.to_csv("answer_psy_1_2.csv", index=None)

# %% [markdown]
# ## 参考结果：
# df_mental_sum:
#
# ![Image Name](https://cdn.kesci.com/upload/s25kw3lt1f.PNG?imageView2/0/w/960/h/960)
#
# answer：
# ![Image Name](https://cdn.kesci.com/upload/s2m3iyhk7u.PNG?imageView2/0/w/960/h/960)

# %% [markdown]
# ## STEP5: 提交 csv 文件，获取分数结果
# 经过上述几个步骤，你的 csv 答案文件已经准备完毕了，最后让我们提交答案文件，看看是否正确。
#
# **提交方法：**
#
# 1、拷贝提交 token
#
# 去对应关卡的 [提交页面](https://www.heywhale.com/home/competition/652df88ecf318d693e2b20de/submit)，找到闯关题 2 任务，看到了你的 token 嘛？
# 拷贝它。
#
# > 记得：每个任务的 token 不一样。
#
# 2、粘贴到下方 cell 里，替换 XXXXXXX， Shift+Enter，运行 。

# %%
# 运行这个Cell 下载提交工具

# !wget -nv -O heywhale_submit https://cdn.kesci.com/submit_tool/v4/heywhale_submit&&chmod +x heywhale_submit

# 运行提交工具
# 把下方XXXXXXX替换为你的 Token
# 改完看起来像是：!./heywhale_submit -token 586eeef71cb92941 -file answer_psy_1_2.csv

# !./heywhale_submit -token XXXXXXX -file answer_psy_1_2.csv  # 替换XXXXXXX；注意不可增减任何空格或其他字符

# %% [markdown]
# 运行成功、显示提交完成后，即可去 [提交页面](https://www.heywhale.com/home/competition/652df88ecf318d693e2b20de/submit) 看成绩。满分即可继续完成下个闯关题。
#
# 没有成功也不怕，看下报错信息，对照教案与[小黄鸭 debug 法](https://baike.baidu.com/item/%E5%B0%8F%E9%BB%84%E9%B8%AD%E8%B0%83%E8%AF%95%E6%B3%95/16569594)排查下，改完重新走 STEP 5、6 提交咯。
