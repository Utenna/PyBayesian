# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## STEP1：查看需要反向计分的列
#
# 1. 读取 **"EverythingIsEffort"** 列的数据
# 2. 获取该列的取值水平(例如，该列的数据为7,7,8,9...，那么数据的取值水平为7,8,9)
# 3. 将获得的取值水平复制给变量**a1**，并将其按从大到小进行排序，(例如排序结果为9,8,7)
# 4. 打印排序后变量**a1**的结果，通过 print 函数进行打印

# %% [markdown]
# ### 参考思路：

# %%
df_dem = pd.read_csv("...") # 输入数据挂载路径
# 提取值的种类可使用.unique()
# 使用np.sort()进行排序，出来的结果默认是从小到大，再使用[::-1]进行倒序
# 最后注意将结果赋值给a1
a1 = ...

# %% [markdown]
# ## STEP2：查看需要反向计分的列
#
# 1. 读取"EverythingIsEffort"列的数据
# 2. 对这一列中的数值进行重新编码（如：将4重新编码为0，将3重新编码为1，将2重新编码为2，将1重新编码为3，将0重新编码为4） 并生成新的一列 **"EverythingIsEffort_recode"**
#
# 此题可能的方法可参考：https://www.sfu.ca/~mjbrydon/tutorials/BAinPy/05_recode.html

# %%
df_dem["..."]
bef_recode = [4, 3, 2, 1, 0] #列出这一列中的数值
afte_recode = [.., .., .., .., .. ] #列出以上数值重新编码后的新值
df_dem["EverythingIsEffort_recode"] =...  #对原来的列使用replace函数

# %% [markdown]
# ## STEP3: 计算几列分数的总和
# 1. 提取数据框中的这几列： **"Nervous","Hopeless","RestlessFidgety","Depressed","EverythingIsEffort_recode","Worthless"**
# 2. 计算这几列分数的总和，将结果储存在新的一列中
# 2.  生成一个新的数据集**df_mental_sum**，其中一列是被试编号，命名为 **"worker_id"** ，另一列是分数总和，命名为 **"sum"**
# 4.  **选取** "sum"列的最后10个值，将结果存在**a2**中

# %%
# 提取数据框的相应列
df_dem[["...","...",...]]

#对这几列进行求和，并将结果储存在新列“sum”中
df_dem['sum'] =... 

#提取数据框中的worker_id列，sum列
df_dem[["...","..."]]

#赋值给一个新的数据框
df_mental_sum = ...

#选取sum列，再使用iloc选择最后10行（-10）
a2 = df_mental_sum['sum'].iloc[...]
