# %% [markdown]
# [![Image Name](https://cdn.kesci.com/upload/s2pw1in29.jpg)](https://www.heywhale.com/home/competition/652df88ecf318d693e2b20de/content/1)
#
# # 闯关题 1：
# ## 🎯题目要求
#
# 我们已经大致学习过使用 numpy 来创建数组、提取部分数组以及在数组中进行计算。
#
# 本题主要考察使用 numpy 来生成不同类型的数组，结合了少部分pandas与画图的知识。
#
# 💡 **友情提醒：**
#
# 为确保每个人生成相同的结果，便于评卷，确保在生成数据之前设定随机种子 123
#
#  👩‍🏫**在遇到困难时可以查看附带的解题思路~**

# %%
import numpy as np
import pandas as pd

np.random.seed(123)

# %% [markdown]
# ## STEP1：生成被试编号
# 1. 生成100个被试编号，格式为"sub_xx"，如sub_01，sub_02...sub_100
# 2. 从其中选取编号为奇数的被试，如sub_01, sub_03,...sub_99
# 3. 将结果存为sub_array
#
# 🐋：取消注释的快捷键是 ctrl+/

# %%
# sub_array = ...

# %% [markdown]
# ## STEP2：生成不同条件下的反应时
# 1. 生成50个条件A下的反应时，条件A下的反应时服从均值为350，标准差为25的正态分布，变量名存为“rt_A”
# 2. 生成50个条件B下的反应时，条件B下的反应时服从均值为450，标准差为35的正态分布，变量名存为“rt_B”
# 3. 计算条件A与条件B反应时的差值(条件B减去条件A)，变量名存为“rt_diff”
# * 注：将所有生成的反应时存为整数

# %%
# rt_A = ...
# rt_B = ...
# rt_diff = ...

# %% [markdown]
# ## STEP3：转为数据框
# 1. 将被试编号、条件A、B的反应时，与二者差值存在同一个数据框中
# 2. 列名分别为：sub_ID，rt_A，rt_B，rt_diff
# 3. 数据框命名为df_rt
# 4. 选取rt_diff 列的前10个值，存入变量a1中
# 5. 请确保最后a1的变量类型为array，可使用`np.array()`
# > 可使用type(a1)进行查看

# %%
# df_rt = ...
# a1 = ...

# %% [markdown]
#  ## STEP4：绘制泊松分布图
#
# 假设你是一个up主，过去这一年，你发布视频获得的点赞数一般在20-160之间，平均每一周会有100个人给你的视频点赞。
#
# 请你根据现有的数据，绘制点赞人数概率的泊松分布图，并回答下列问题，在下方代码cell中将答案赋值对应的变量 a2 。
#
# >**问题：假设事件A为平均一周有60人给你的视频点赞，事件A发生的概率大约是：
# > A.0%
# > B.2%
# > C.4%**
#
# 步骤参考：
# 1. 生成横坐标数据：点赞数(可参考题目中的点赞数范围)
# 2. 使用scipy中的 st.poisson.pmf() 来生成对应的概率数据
# 3. 绘图(提示：seaborn中接受的数据格式为数据框类型，可以选择转化为数据框后再绘图，或使用matplotlib.pyplot进行绘图)

# %%
#import scipy.stats...
# x = ...
# mu = ...
# ....

# %%
a2 = ''  # 在''中间填写你的答案选项

# %% [markdown]
# ## STEP5：将结果保存为 csv 文件
# 💡 这一步的代码你无需修改，直接运行即可。

# %%
# 运行这两个cell,生成答案文件；
# 该文件在左侧文件树project工作区下，你可以自行右击下载或者读取查看

a1 = a1.tolist()

answer = pd.DataFrame({"id": ["q1", "q2"],
                        "answer": [a1,a2]})

answer.to_csv("answer_psy_1_1.csv", index=None)

# %% [markdown]
# ## 参考结果（部分截图）：
# df_rt:
# ![Image Name](https://cdn.kesci.com/upload/s2jxqhg5fz.PNG?imageView2/0/w/960/h/960)
#
# answer:
#
# ![Image Name](https://cdn.kesci.com/upload/s2m22eelr2.PNG?imageView2/0/w/960/h/960)

# %% [markdown]
# ## STEP6: 提交 csv 文件，获取分数结果
# 经过上述几个步骤，你的 csv 答案文件已经准备完毕了，最后让我们提交答案文件，看看是否正确。
#
# **提交方法：**
#
# 1、拷贝提交 token
#
# 去对应关卡的 [提交页面](https://www.heywhale.com/home/competition/652df88ecf318d693e2b20de/submit)，找到闯关题 1 任务，看到了你的 token 嘛？
# 拷贝它。
#
# > 记得：每个任务的 token 不一样。
#
# 2、粘贴到下方 cell 里，替换 XXXXXXX， Shift+Enter，运行 。

# %%
# 运行这个Cell 下载提交工具

# !wget -nv -O heywhale_submit https://cdn.kesci.com/submit_tool/v4/heywhale_submit&&chmod +x heywhale_submit

# 运行提交工具
# 把下方XXXXXXX替换为你的 Token
# 改完看起来像是：!./heywhale_submit -token 586eeef71cb92941 -file answer_psy_1_1.csv

# !./heywhale_submit -token XXXXXXX -file answer_psy_1_1.csv  # 替换XXXXXXX；注意不可增减任何空格或其他字符

# %% [markdown]
# 运行成功、显示提交完成后，即可去 [提交页面](https://www.heywhale.com/home/competition/652df88ecf318d693e2b20de/submit) 看成绩。满分即可继续完成下个闯关题。
#
# 没有成功也不怕，看下报错信息，对照教案与[小黄鸭 debug 法](https://baike.baidu.com/item/%E5%B0%8F%E9%BB%84%E9%B8%AD%E8%B0%83%E8%AF%95%E6%B3%95/16569594)排查下，改完重新走 STEP 5、6 提交咯。
