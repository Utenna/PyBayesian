# %% [markdown]
# # 闯关题 3：
# > 🔈之前的关卡专注于数据操作处理和可视化，本关卡针对于贝叶斯概率分布相关的技能。
#
# ## 🌟 目标解锁 🚀📊
# 1. 定义概率分布
# 2. 概率分布可视化
# 3. 概率分布的统计量
# 4. 通过数据和统计量计算概率分布

# %%
# 导入必要的工具包
import preliz as pz
import matplotlib.pyplot as plt

# 设置绘图风格
pz.style.library["preliz-doc"]["figure.dpi"] = 100
pz.style.library["preliz-doc"]["figure.figsize"] = (10, 4)
pz.style.use("preliz-doc")

# %% [markdown]
# ## STEP1：定义概率分布
#
# 1. 问题q1：使用 `PreliZ` 定义 Beta 分布，参数 `alpha = 2`, `beta = 5`，并生成符合分布的样本
#    - 要求1：使用 `.rvs()` 方法。
#    - 要求2：为保证结果一致性，请在`.rvs()`函数里添加参数`random_state=123`。
#    - 要求3：把变量存为a1。
# 2. 问题q2：定义 Beta 分布，参数 `alpha = 2`, `beta = 5`，并绘制概率密度函数。
# 3. 问题q3：定义 Possion 分布，参数 `pi = 4.3`，并绘制概率密度函数。
# 4. 问题q4：定义 Gamma 分布，参数 `alpha = 2`, `beta = 1`，并绘制概率密度函数。

# %%
# 使用 `PreliZ` 定义 Beta 分布，参数 `alpha = 2`, `beta = 5`，并生成符合分布的样本。
# dist = ...
# beta_samples = dist.rvs(...,random_state=123) # 设置随机种子123

# %%
# 问题q2：定义 Beta 分布，参数 `alpha = 2`, `beta = 5`

# %%
# 问题q3：定义 Possion 分布，参数 `pi = 4.3`，并绘制概率密度函数。

# %%
# 问题q4：定义 Gamma 分布，参数 `alpha = 2`, `beta = 1`，并绘制概率密度函数。

# %% [markdown]
# ## STEP2：概率分布可视化
#
# 1. 问题q1：定义 Gamma 分布，参数 `alpha = 2`, `beta = 1`，并绘制累积分布函数(cumulative distribution function)。提示：`.plot_cdf`。
# 2. 问题q2：在问题1的基础上绘制百分位函数(quantile function)。提示：`.plot_ppf`。
# 3. 问题q3：使用 `.plot_interactive` 方法绘制可交互的累积分布函数。并尝试调整参数值，观察分布函数的变化。

# %%
# 问题q1：定义 Gamma 分布，参数 `alpha = 2`, `beta = 1`，并绘制累积分布函数(cumulative distribution function)。

# %%
# 问题q2：在问题1的基础上绘制百分位函数(quantile function)。提示：`.plot_ppf`。

# %%
# 问题q3：使用 `.plot_interactive` 方法绘制可交互的累积分布函数。并尝试调整参数值，观察分布函数的变化。
# 使用可交互方法绘制累积分布函数

# %% [markdown]
# ## STEP3：概率分布的统计量
#
# 定义 Gamma 分布，参数 `alpha = 2`, `beta = 1`，计算其统计量。
# 1. 问题q1：计算 Gamma 分布的均值和中位数。
#      - 提示，可以使用 `.median` 方法计算中位数，或者先通过 `.rv` 方法生成样本，在通过 `np.median` 计算中位数。
# 2. 问题q2：计算 Gamma 分布的最高密度区间(highest density interval)。
# 3. 问题q3：通过 `.summary` 显示 Gamma 分布的常见统计量。
# 4. 问题q4：计算 Gamma 分布在 [0.1,0.5,0.9]的百分位数。提示：`.ppf`。
# 5. 问题q5：计算数据值 `x=3` 在 Gamma 分布下的对数似然值。提示：`.logpdf`。

# %%
import numpy as np
np.random.seed(12345) # 设置随机点种子，请勿修改

# 定义 Gamma 分布，参数 `alpha = 2`, `beta = 1`
dist = pz.Gamma(2, 1)

# 问题q1：计算 Gamma 分布的均值和中位数。

# %%
# 问题q2：计算 Gamma 分布的最高密度区间(highest density interval)。

# %%
# 问题q3：通过 `.summary` 显示 Gamma 分布的常见统计量。

# %%
# 问题q4：计算 Gamma 分布在 [0.1,0.5,0.9]的百分位数。

# percentiles = ...
# gamma_percentile = ...

# %%
# 问题q5：计算数据值 `x=3` 在 Gamma 分布下的对数似然值。
x = 3
# gamma_logp = ...
# print(f'Log-Likelihood for x={x}: {gamma_logp}')

# %% [markdown]
# ## STEP4：通过数据和统计量计算概率分布
#
# 1. 问题q1：通过最大熵方法 `pz.maxent` 计算区间在[0.3, 0.8]之间，概率为0.6的正态分布的均值和方差。
#       - 提示，pz.maxent 输入的第一个参数为分布，第二、三个参数为区间的上下界，第四个参数为该区间的概率占比。
# 2. 问题2：通过 `pz.quartile` 方法计算四分位值为 [1,3,5] 下正态分布的均值和方差。
#       - 提示，pz.quartile 输入的第一个参数为分布，第二至五个参数为四分位值。

# %%
# 问题q1：通过最大熵方法 `pz.maxent` 计算区间在[0.3, 0.8]之间，概率为0.6的正态分布的均值和方差。
# dist = pz.Normal()
# pz.maxent(dist, ...)

# %%
# 问题2：通过 `pz.quartile` 方法计算四分位值为 [1,3,5] 下正态分布的均值和方差。
# 计算四分位值为 [1, 3, 5] 下正态分布的均值和方差

# 定义正态分布
normal_dist = pz.Normal()


# ... = pz.quartile(...)
# quartile_mu = ...
# quartile_sigma = ...

# %% [markdown]
# ## STEP4：将结果保存为 csv 文件
# 💡 这一步的代码你无需修改，直接运行即可。

# %%
import pandas as pd

result1 = pd.DataFrame(beta_samples)
result1.to_csv("result31.csv", index=None)

result2 = pd.DataFrame(
    {
        "gamma_mean": [round(gamma_mean,2)],
        "gamma_median": [round(gamma_median,2)],
        "gamma_hdi1": [round(gamma_hdi[0],2)],
        "gamma_hdi2": [round(gamma_hdi[1],2)],
        "gamma_percentile1": [round(gamma_percentile[0],2)],
        "gamma_percentile2": [round(gamma_percentile[1],2)],
        "gamma_percentile3": [round(gamma_percentile[2],2)],
        "gamma_logp":[round(gamma_logp,2)]
    }
)
result2.to_csv("result32.csv", index=None)

result3 = pd.DataFrame(
    {
        "maxent_mean": [round(maxent_mu,2)],
        "maxent_sd": [round(maxent_sigma,2)],
        "mean_quartile": [round(quartile_mu,2)],
        "variance_quartile": [round(quartile_sigma,2)]
    }
)
result3.to_csv("result33.csv", index=None)

# %% [markdown]
# ## STEP5: 提交 csv 文件，获取分数结果
# 经过上述几个步骤，你的 csv 答案文件已经准备完毕了，最后让我们提交答案文件，看看是否正确。
#
# **提交方法：**
#
# 1、拷贝提交 token
#
# 去对应关卡的 [提交页面](https://www.heywhale.com/home/competition/652df88ecf318d693e2b20de/submit)，找到闯关题 1 任务，看到了你的 token 嘛？
# 拷贝它。
#
# > 记得：每个任务的 token 不一样。
#
# 2、粘贴到下方 cell 里，替换 XXXXXXX， Shift+Enter，运行 。

# %%
# 运行这个Cell 下载提交工具

# !wget -nv -O heywhale_submit https://cdn.kesci.com/submit_tool/v4/heywhale_submit&&chmod +x heywhale_submit

# 运行提交工具
# 把下方XXXXXXX替换为你的 Token
# 改完看起来像是：!./heywhale_submit -token 586eeef71cb92941 -file answer_psy_1_1.csv

# !./heywhale_submit -token XXXXXXX -file answer_psy_1_1.csv  # 替换XXXXXXX；注意不可增减任何空格或其他字符
# Out:
# 2024-09-25 07:21:27 URL:https://cdn.kesci.com/submit_tool/v4/heywhale_submit [22020102/22020102] -> "heywhale_submit" [1]
# Heywhale Submit Tool: v5.0.1
#
# =========================
# > 错误: 文件校验失败
# > 文件不存在, answer_psy_1_1.csv
