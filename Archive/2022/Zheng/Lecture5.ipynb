# %% [markdown]
# # Lecture 5: Prior
#
# ## Instructor： 胡传鹏（博士）[Dr. Hu Chuan-Peng]
#
# ### 南京师范大学心理学院[School of Psychology, Nanjing Normal University]

# %% [markdown]
# 学习目标：
# - 先验是什么？
# - 为什么需要先验，先验重要吗？
# - 如何在模型中构建先验？
# - 主观与客观之争：先验是一种主观操作？频率学派更客观？
#
#
# ![Image Name](https://cdn.kesci.com/upload/image/ril3rktwk9.png?imageView2/0/w/960/h/960)

# %% [markdown]
# 回顾：
#
# 在探究地球有多少表面被水覆盖的问题中。
#
# 我们通过将地球抛到空中，并且以当你抓住它时右手食指下的表面是水还是陆地进行实验。通过重复上述步骤不断的收集证据，我们可以慢慢地接近真相。
#
# **当我们在没有获得数据时**
# 我们可能认为陆地和水面出现是相同的，即为均匀分布（下图中的虚线部分）。
#
# $p \sim U(0,1)$

# %% [markdown]
# 比如 10次的结果如下(W代表水，L代表陆地)：L W L L W W W L W W。
#
# **每一次事件发生，都可能会改变我们都对概率认知:**
#
# ![Image Name](https://cdn.kesci.com/upload/image/rhqd6akbc6.gif?imageView2/0/w/640/h/640)

# %% [markdown]
# 虽然先验会随着获得数据不断更新，但是先验的不同也会对我们的判断产生影响。
#
# **不同的先验和数据(似然)会产生不同的后验分布**
#
# ![Image Name](https://cdn.kesci.com/upload/image/rhqcb9gji7.png?imageView2/0/w/960/h/960)

# %% [markdown]
# 本节课的关注点就在于更深入的**了解先验的含义**与**不同的先验如何带来不同的影响**。

# %% [markdown]
# ### 先验概率与似然

# %% [markdown]
# 如何通过概率去描述先验？如何理解先验概率的意义？
#
# 在前面我们已经学习了**似然与概率**的关系，在这里我们可以凭借与似然的对比去理解先验概率的含义。

# %% [markdown]
# 接着以探究地球海水覆盖率为例。
# - **似然指在参数已知的情况下，数据出现的概率**。
#
# 比如，已知海水的覆盖率为50%（参数），那么扔10地球，得到5次海水和5次陆地的**似然**是0.5。
#
# 已知海水的覆盖率为100%（参数），那么扔10地球，得到5次海水和5次陆地的**似然**是0。
#
#
# ![Image Name](https://cdn.kesci.com/upload/image/ripe5fpwy6.png?imageView2/0/w/960/h/960)
#
# 当然我们，海水的覆盖率也可能为0.3，或者0.7.
#
#
# ![Image Name](https://cdn.kesci.com/upload/image/ripe6s5jz5.png?imageView2/0/w/960/h/960)

# %% [markdown]
# - **概率指的是参数真实出现的可能性**。
#
# 比如，已知真实的海水覆盖率为0.7。
#
#
# ![Image Name](https://cdn.kesci.com/upload/image/ripg4o6z7f.png?imageView2/0/w/960/h/960)

# %% [markdown]
# - **先验概率指，在获得数据之前对于参数出现的信念或者概率**。
#
# 比如，在未获得数据时，我们可以先验的认为地球上海面覆盖率为0.5，当然也可以认为是0.7，甚至认为它可以是0到1的任何值。这个推测是主观的。
#
# ![Image Name](https://cdn.kesci.com/upload/image/rip14lldva.png?imageView2/0/w/960/h/960)

# %% [markdown]
# 🧐 总结：概率是关于海水覆盖率的概率分布，似然是在海水覆盖率已知的前提下通过实验收集不同数据的可能。
#
# 先验概率与概率的定义类似，是我们在**未获得数据时**对海水覆盖率的概率分布的推测。

# %% [markdown]
# #### valid probability distribution vs. likelihood

# %% [markdown]
# 对比似然和先验概率的分布图可以发现，所有事件下似然的总和不等于1。
#
# 比如，似然分布下的面积总和为 1/3。
# ![Image Name](https://cdn.kesci.com/upload/image/ripg9yfx96.png?imageView2/0/w/960/h/960)
#
# 这说明**似然不是有效的概率分布**。
#
#
# 而先验概率与后验概率一样，在所有事件下概率的总和为1，是有效的概率分布。
#
# ![Image Name](https://cdn.kesci.com/upload/image/ripglmb9nq.png?imageView2/0/w/960/h/960)
#
#
# 因此，通过似然进行统计推断不是有效的推断。

# %% [markdown]
# #### 离散与连续

# %% [markdown]
# 无论是似然还是先验概率，我们发现，可以通过增加事件的数量将离散的事件变为连续的变量。
#
# ![Image Name](https://cdn.kesci.com/upload/image/ripggbklwc.png?imageView2/0/w/960/h/960)

# %% [markdown]
# #### informative vs. uninformative

# %% [markdown]
# 前面展示了，先验概率可以由主观设定。但后验概率由先验概率和似然组成，因此设置不同的先验概率对于似然和后验的影响是不同的。
#
# 比如，先验概率假设所有事件出现的概率都一样时。此时概率分布完全受到似然的影响，这样的先验概率就是 uninformative （无信息）的先验。
#
# 与之相对的，当我们先验的认为某些事件出现的可能性大于另一些事件时，此时的先验就是 informative （有信息的）。
#
# 比如，我们有很强的先验认为海水的覆盖面积为0.7，那么此时即使获得扔10次地球有8次陆地的数据，我们得到的后验概率也更倾向于先验。
# 此时先验概率对似然和后验概率影响很大。

# %% [markdown]
# ### 先验概率与频率论点估计

# %% [markdown]
# 即使我们知道了可以主观的设置先验概率，但是它对于统计的意义是什么？
#
# 这需要结合频率论中的点估计进行理解。
#
# 在前面学习过最大似然估计后我们了解到，最大似然是根据数据推测参数值，并且这个推测过程是一个点估计的过程，因此符合频率学派的假设。
# 频率学派的假设为：
# - 参数是真实存在且不会变化的固定真值。比如，硬币朝上的概率为0.5，这个概率是不会因为扔硬币这个事件导致概率发生变化。
# - 可以通过可以重复多次的方法来估计该真值。比如，虽然扔两三次硬币难以估计硬币朝上的概率，但是通过无限的重复，我们可以得到的估计会越来越接近正值。
#
# 频率学派的问题在于：
# - 参数真值可能并不固定。比如心理特征可能不存在固定不变的正值。
# - 无法完成反复的测量。比如第一次对于心理特征的测量会影响第二次测量，或者对于癌症病人很少能获得其患两次相同癌症的数据。

# %% [markdown]
# 为了解决频率学派的问题，贝叶斯学派，将概率引入参数当中，允许参数发生变化。
#
# 为了使得对参数的估计从点估计变化为概率估计。我们需要似然函数$p(data|\theta)$以及先验分布$p(\theta)$。
#
# 即通过贝叶斯公式$p(\theta|data)=p(data|\theta)p(\theta)$，将似然函数$p(data|\theta)$假设的“数据从参数中生成”的过程逆转为 后验概率$p(\theta|data)$假设的“参数从数据中生成”的过程。
#
# 可见，要完成这个过程，先验必不可少。

# %% [markdown]
# ### 信念 vs. 概率

# %% [markdown]
# 对于先验其实有两种不同的理解方式：
#
# 1. 将先验理解为参数的**客观可变性**。这个理解可以从频率论点估计出发，此时的先验概率和后验概率都表达了对于点估计结果的不确定性（**uncertainty**），即参数不是固定不变的，参数的值取决于真值和噪音。
#
# 2. 将先验理解为对参数的**主观信念**。另一种理解方式认为参数固定不变，但是我们对他的信心和信念有所不同。比如对于硬币朝上的概率为0.5，即参数为0.5，我们可以完全的相信这个参数，也可以相信该参数为0，1或者其他值。
#
# 这两种方式殊途同归，虽然理解的角度不同，但都致力于解释频率学派点估计存在的问题。

# %% [markdown]
# #### 先验的主观性

# %% [markdown]
# 虽然先验的设定可以弥补频率学派点估计的问题，但是先验是主观设定的，这是否会导致统计结果不够客观？
#
# 正如第一节课所提到的：**任何统计分析方法都不可能完全客观，因此主观性是一个相对概念: **
#
# * 一方面，相对于频率学派的主观性暗含在各种**前提预设**中，贝叶斯学派通过设定先验的方式来体现主观性，这更加透明，不易让人产生误解。
#
# * 另一方面，更为宏观的来说，样本的抽取，数据清理方式的选择，分析方法的选择，$p$值的设定，这些都存在主观性。因此，频率学派并没有想象的那么‘客观’。
#
#
# 因此， 主观不一定是坏事，如何合理利用主观性才是问题的关键。

# %% [markdown]
# 接下来我们将通过实例演示，如何根据贝叶斯公式利用数据更新先验，讨论先验对于数据分析的影响，以及如何设置合理的先验概率分布。

# %% [markdown]
# ## Part 2: How to combine likelihood and prior to form a posterior

# %% [markdown]
# 接下来我们将介绍贝叶斯公式背后的机制，尤其是先验的改变会如何影响到后验分布

# %% [markdown]
# 下面的例子提供了一种关于贝叶斯规则的直觉理解

# %% [markdown]
# ![Image Name](https://cdn.kesci.com/upload/image/rippmmozqo.png?imageView2/0/w/960/h/960)
#
#
#
# 假设我们有一个盒子，盒子里装了5个球。每个球有两种颜色，红色和白色。在将球摸上来之前，我们无法得知球的颜色。每条球有1/2的概率为白色或红色。

# %% [markdown]
# ![Image Name](https://cdn.kesci.com/upload/image/rippmwx348.png?imageView2/0/w/960/h/960)
#
#
# 当我们摸到一个球，我们得知这个球是红色的，现在我们需要根据摸到的这个球的颜色来判断盒子中红球的数量。

# %% [markdown]
# 由于我们事先并没有得到任何有关这个盒子中球的数量的信息，故我们假定这个盒子中红球的数量的概率是均匀分布的，且各种数量的红球出现的概率之和为1
#
# ![Image Name](https://cdn.kesci.com/upload/image/rim7bryhkb.png?imageView2/0/w/960/h/960)

# %%
# numpy 是专门用于数组运算的包
import numpy as np

# 从scipy.stats里载入均匀分布的函数
from scipy.stats import uniform

# matplotlib.pyplot 是专门用于画图的包
import matplotlib.pyplot as plt

# 起点为0，终点为6(不包括6)，步长为1生成6个数
x = np.arange(start = 0, stop = 6, step = 1)

# 均匀分布的概率密度函数,x为变量，0为均匀分布起点，6为均匀分布的点的数量
y_prior = uniform.pdf(x,loc = 0,scale = 6)

# 画条形图
plt.bar(x,y_prior,width=0.5)

# 添加标题
plt.title("Prior")

# 添加y轴标签
plt.ylabel("probability")

print(f"盒子里的球的数量分别为0,1,2,3,4,5的情况下，先验概率分别为{y_prior}")
# Out:
# 盒子里的球的数量分别为0,1,2,3,4,5的情况下，先验概率分别为[0.16666667 0.16666667 0.16666667 0.16666667 0.16666667 0.16666667]
# <img src="https://cdn.kesci.com/upload/rt/C2EB3B9334894FAB8B795EE4445FF684/rirq51yfrp.png">

# %% [markdown]
# 我们假定X为摸到的球的颜色
#
# $X \in \left \{ 0,1 \right \}$
#
# $X = 0$代表白球
#
# $X = 1$代表红球
#
# 当我们摸到一个球，这只球是红球，那么我们该如何推断盒子中球的总数？

# %% [markdown]
# 假定盒子中有$\alpha$个球，$\alpha \in \left \{ 0,1,2,3,4,5 \right \}$
#
# 在不同$\alpha$条件下，观察到一个红鱼的概率为$Pr(X=1|Y = \alpha) = \alpha/5$
#
# 根据上节课学到的知识，我们知道这个是不同$\alpha$条件下，我们观察到一个球是红球的似然

# %% [markdown]
# ![Image Name](https://cdn.kesci.com/upload/image/rim9g45c3.png?imageView2/0/w/960/h/960)

# %%
# numpy 是专门用于数组运算的包
import numpy as np

# matplotlib.pyplot 是专门用于画图的包
import matplotlib.pyplot as plt

# 起点为0，终点为6(不包括6)，步长为1生成5个数
x = np.arange(start = 0, stop = 6, step = 1)

# Pr(X=1|Y = \alpha) = \alpha/5
y_likelihood = x/5
# 画条形图
plt.bar(x,y_likelihood,width=0.5)

# 添加标题
plt.title("Likelihood")

# 添加y轴标签
plt.ylabel("likelihood")

print(f"盒子里的球的数量分别为0,1,2,3,4,5的情况下,似然分别为{y_likelihood}")
# Out:
# 盒子里的球的数量分别为0,1,2,3,4,5的情况下,似然分别为[0.  0.2 0.4 0.6 0.8 1. ]
# <img src="https://cdn.kesci.com/upload/rt/01C351D281A94360976F3A95B2D6E8EE/rirq529ges.png">

# %% [markdown]
# **Bayes' rule**
#
#
# $P(\theta|data) = \frac{P(data|\theta)*P(\theta)}{P(data)}$
# $P(\theta|data) \propto P(data|\theta)*P(\theta)$

# %% [markdown]
# 根据贝叶斯定理，我们在给定当前观察到的现象的情况下，对参数的概率的信念会随着参数的先验概率和给定参数下的似然而发生信念的更新

# %% [markdown]
# ![Image Name](https://cdn.kesci.com/upload/image/ripqya7f6w.png?imageView2/0/w/960/h/960)

# %%
# numpy 是专门用于数组运算的包
import numpy as np

# matplotlib.pyplot 是专门用于画图的包
import matplotlib.pyplot as plt

# 起点为0，终点为6(不包括6)，步长为1生成5个数
x = np.arange(start = 0, stop = 6, step = 1)

# p(data) = \sum{p(data|\theta)p(\theta)}
y_margin = np.sum(y_prior*y_likelihood)


# P(\theta|data) = \frac{P(data|\theta)*P(\theta)}{P(data)} 
y_posterior = (y_prior*y_likelihood)/y_margin

# 画条形图
plt.bar(x,y_posterior,width=0.5)

# 添加标题
plt.title("Posterior")

# 添加y轴标签
plt.ylabel("Posterior")

print(f"盒子里的球的数量分别为0,1,2,3,4,5的情况下,后验概率分别为{y_posterior}")
# Out:
# 盒子里的球的数量分别为0,1,2,3,4,5的情况下,后验概率分别为[0.         0.06666667 0.13333333 0.2        0.26666667 0.33333333]
# <img src="https://cdn.kesci.com/upload/rt/FA16752A64B440B88C2579EC2822EE1D/rirq52csgg.png">

# %%
# numpy 是专门用于数组运算的包
import numpy as np

# matplotlib.pyplot 是专门用于画图的包
import matplotlib.pyplot as plt

# 从scipy.stats里载入均匀分布的函数
from scipy.stats import uniform


# 起点为0，终点为6(不包括6)，步长为1生成5个数
x = np.arange(start = 0, stop = 6, step = 1)

# 均匀分布的概率密度函数,x为变量，0为均匀分布起点，6为均匀分布的点的数量
y_prior = uniform.pdf(x,loc = 0,scale = 6)

# Pr(X=1|Y = \alpha) = \alpha/5
y_likelihood = x/5

# p(data) = \sum{p(data|\theta)p(\theta)}
margin = np.sum(y_prior*y_likelihood)

# 袋中红球的数量为0
nx = 0

# 袋中红球的数量为0时的先验概率
prior = y_prior[nx]

# 袋中红球的数量为0时的似然
likelihood = y_likelihood[nx]

# 袋中红球数量为0时的后验概率
posterior = (prior*likelihood)/margin


print(f"盒子里的球的数量分别为{nx}的情况下,后验概率分别为{posterior}")
# Out:
# 盒子里的球的数量分别为0的情况下,后验概率分别为0.0

# %%
######################################################
# 练习阶段
# Tips:思考如何表征盒子中不同红球的数量
# 目的：求出不同的红球数量下的后验概率
######################################################
# numpy 是专门用于数组运算的包
from tkinter import N
import numpy as np

# matplotlib.pyplot 是专门用于画图的包
import matplotlib.pyplot as plt

# 从scipy.stats里载入均匀分布的函数
from scipy.stats import uniform


# 起点为0，终点为6(不包括6)，步长为1生成5个数
x = np.arange(start = 0, stop = 6, step = 1)

# 均匀分布的概率密度函数,x为变量，0为均匀分布起点，6为均匀分布的点的数量
y_prior = uniform.pdf(x,loc = 0,scale = 6)

# Pr(X=1|Y = \alpha) = \alpha/5
y_likelihood = x/5

# p(data) = \sum{p(data|\theta)p(\theta)}
margin = np.sum(y_prior*y_likelihood)

# 袋中红球的数量为...（请将...换成红球数量）
nx = ...

# 袋中红球的数量为0时的先验概率
prior = y_prior[nx]

# 袋中红球的数量为0时的似然
likelihood = y_likelihood[nx]

# 袋中红球数量为0时的后验概率
posterior = (prior*likelihood)/margin


print(f"盒子里的球的数量分别为{nx}的情况下,后验概率分别为{posterior}")
# Out:
#   File "/tmp/ipykernel_46/1703682711.py", line 30
#     nx = &&&
#          ^
# SyntaxError: invalid syntax

# %% [markdown]
# ![Image Name](https://cdn.kesci.com/upload/image/rir5vollzd.png?imageView2/0/w/960/h/960)

# %% [markdown]
# ![Image Name](https://cdn.kesci.com/upload/image/rir5tgtcxq.png?imageView2/0/w/960/h/960)

# %% [markdown]
# 当先验发生改变时，会发生什么变化呢？
#
# 若我们提前知道盒子里两种颜色的球的数量很接近，那么先验该怎么改变呢？

# %% [markdown]
# 盒子里更有可能会有两个或三个红色或白色的球，而0个或5个红色或白色的球的概率最低，于是形成了新的先验。
#
# 盒子里的球的数量分别为0，1，2，3，4，5，的情况下，先验概率分别为[1/12, 1/6, 1/4, 1/4, 1/6, 1/12]
#
#
# ![Image Name](https://cdn.kesci.com/upload/image/rimvt3cx1p.png?imageView2/0/w/960/h/960)

# %%
######################################################
# 练习阶段
#
# Tips1: 改变哪个变量可以为先验概率赋值 
# Tips2: 改变哪个变量可以表示盒子中不同红球的数量
#
# 目的1：先验概率如何表征
# 目的2：求出不同的红球数量下的后验概率
######################################################
# numpy 是专门用于数组运算的包
import numpy as np

# matplotlib.pyplot 是专门用于画图的包
import matplotlib.pyplot as plt

# 从scipy.stats里载入均匀分布的函数
from scipy.stats import uniform


# 起点为0，终点为6(不包括6)，步长为1生成5个数
x = np.arange(start = 0, stop = 6, step = 1)

# 盒子里的球的数量分别为0，1，2，3，4，5，的情况下，先验概率分别为[1/12, 1/6, 1/4, 1/4, 1/6, 1/12]
# 请你根据上述情况将...修改
y_prior = ...

# Pr(X=1|Y = \alpha) = \alpha/5
y_likelihood = x/5

# p(data) = \sum{p(data|\theta)p(\theta)}
margin = np.sum(y_prior*y_likelihood)

# 袋中红球的数量为&&&
nx = &&&

# 袋中红球的数量为0时的先验概率
prior = y_prior[nx]

# 袋中红球的数量为0时的似然
likelihood = y_likelihood[nx]

# 袋中红球数量为0时的后验概率
posterior = (prior*likelihood)/margin


print(f"盒子里的球的数量分别为{nx}的情况下,后验概率分别为{posterior}")

# %% [markdown]
# ![Image Name](https://cdn.kesci.com/upload/image/rir5x038ll.png?imageView2/0/w/960/h/960)

# %% [markdown]
# ![Image Name](https://cdn.kesci.com/upload/image/rir5xrq6v4.png?imageView2/0/w/960/h/960)

# %% [markdown]
# ### 应用
#
# 假定我们旋转地球仪，手指落在陆地上的概率为为$\theta$,我们旋转10次中发现有3次手指指向为陆地；
#
# 手指指向陆地的次数为Z；
#
# 在这种情况下，我们的似然为
#  $\operatorname{Pr}(Z = 3\mid \theta) = \binom{10}{3} \theta^{3}(1-\theta)^{10-3}$

# %% [markdown]
# 在旋转地球仪之前，我们认为手指指在陆地上的概率是均匀分布的。

# %%
# numpy 是专门用于数组运算的包
import numpy as np

# 从scipy.stats里输入均匀分布的函数
from scipy.stats import uniform

# matplotlib.pyplot 是专门用于画图的包
import matplotlib.pyplot as plt



# 起点为0，终点为1(不包括1)，步长为0.01生成数组
x = np.arange(start = 0, stop = 1, step = 0.01)

# 均匀分布的概率密度函数,x为变量，0为均匀分布起点，100为均匀分布的点的数量
y_prior = uniform.pdf(x,loc = 0,scale = 100)

# 画折线图
plt.plot(x,y_prior)

# 添加标题
plt.title("Prior")

# 添加y轴标签
plt.ylabel("probability")

# %%
# numpy 是专门用于数组运算的包
import numpy as np

# matplotlib.pyplot 是专门用于画图的包
import matplotlib.pyplot as plt


# 起点为0，终点为1(不包括1)，步长为0.01生成数组
x = np.arange(start = 0, stop = 1, step = 0.01)

# comb这个函数是专门用来算组合数的
from scipy.special import comb

theta = x

#  $\operatorname{Pr}(Z = 3\mid \theta) = \binom{10}{3} \theta^{3}(1-\theta)^{10-3}$
y_likelihood = comb(10,3)*((theta)**(3))*((1-theta)**(10-3))
# 画条形图
plt.plot(x,y_likelihood)

# 添加标题
plt.title("Likelihood")

# 添加y轴标签
plt.ylabel("likelihood")

# %%
# numpy 是专门用于数组运算的包
import numpy as np

# matplotlib.pyplot 是专门用于画图的包
import matplotlib.pyplot as plt

# 起点为0，终点为1(不包括1)，步长为0.01生成数组
x = np.arange(start = 0, stop = 1, step = 0.01)


# P(\theta|data) = \frac{P(data|\theta)*P(\theta)}{P(data)} 
y_posterior = (y_prior*y_likelihood)/np.sum(y_prior*y_likelihood)

# 画折线图
plt.plot(x,y_posterior)


# 添加标题
plt.title("Posterior")

# 添加y轴标签
plt.ylabel("probability density")

# %% [markdown]
# 在我们认为手指落在陆地上的概率是均值为0.3，标准差为0.1正态分布的之后。

# %%
# numpy 是专门用于数组运算的包
import numpy as np

# 从scipy.stats里输入正态分布的函数
from scipy.stats import norm

# matplotlib.pyplot 是专门用于画图的包
import matplotlib.pyplot as plt



# 起点为0，终点为1(不包括1)，步长为0.01生成数组
x = np.arange(start = 0, stop = 1, step = 0.01)

# 正态分布的概率密度函数,x为变量，0.3为平均值，0.1为标准差
y_prior = norm.pdf(x,0.3,0.1)

# 画折线图
plt.plot(x,y_prior)

# 添加标题
plt.title("Prior")

# 添加y轴标签
plt.ylabel("probability")

# %%
# numpy 是专门用于数组运算的包
import numpy as np

# matplotlib.pyplot 是专门用于画图的包
import matplotlib.pyplot as plt


# 起点为0，终点为1(不包括1)，步长为0.01生成数组
x = np.arange(start = 0, stop = 1, step = 0.01)

# comb这个函数是专门用来算组合数的
from scipy.special import comb

theta = x

#  $\operatorname{Pr}(Z = 3\mid \theta) = \binom{10}{3} \theta^{3}(1-\theta)^{10-3}$
y_likelihood = comb(10,3)*((theta)**(3))*((1-theta)**(10-3))
# 画条形图
plt.plot(x,y_likelihood)

# 添加标题
plt.title("Likelihood")

# 添加y轴标签
plt.ylabel("likelihood")

# %%
# numpy 是专门用于数组运算的包
import numpy as np

# matplotlib.pyplot 是专门用于画图的包
import matplotlib.pyplot as plt

# 起点为0，终点为1(不包括1)，步长为0.01生成数组
x = np.arange(start = 0, stop = 1, step = 0.01)


# P(\theta|data) = \frac{P(data|\theta)*P(\theta)}{P(data)} 
y_posterior = (y_prior*y_likelihood)/np.sum(y_prior*y_likelihood)

# 画折线图
plt.plot(x,y_posterior)


# 添加标题
plt.title("Posterior")

# 添加y轴标签
plt.ylabel("probability density")

# %% [markdown]
# 若我们刻意改变旋转地球仪后手指指向陆地的先验概率，使手指指向陆地的先验概率不可能低于0.3

# %%
# numpy 是专门用于数组运算的包
import numpy as np

# 从scipy.stats里输入正态分布的函数
from scipy.stats import norm

# matplotlib.pyplot 是专门用于画图的包
import matplotlib.pyplot as plt



# 起点为0，终点为1(不包括1)，步长为0.01生成数组
x = np.arange(start = 0, stop = 1, step = 0.01)

# 手指指向陆地的先验概率不可能低于0.5
y_prior = np.concatenate([np.repeat(0,30),np.repeat(1,70)])/np.sum(np.concatenate([np.repeat(0,30),np.repeat(1,70)]))

# 画折线图
plt.plot(x,y_prior)

# 添加标题
plt.title("Prior")

# 添加y轴标签
plt.ylabel("probability")

# %%
# numpy 是专门用于数组运算的包
import numpy as np

# matplotlib.pyplot 是专门用于画图的包
import matplotlib.pyplot as plt


# 起点为0，终点为1(不包括1)，步长为0.01生成数组
x = np.arange(start = 0, stop = 1, step = 0.01)

# comb这个函数是专门用来算组合数的
from scipy.special import comb

theta = x

#  $\operatorname{Pr}(Z = 3\mid \theta) = \binom{10}{3} \theta^{3}(1-\theta)^{10-3}$
y_likelihood = comb(10,3)*((theta)**(3))*((1-theta)**(10-3))
# 画条形图
plt.plot(x,y_likelihood)

# 添加标题
plt.title("Likelihood")

# 添加y轴标签
plt.ylabel("likelihood")

# %%
# numpy 是专门用于数组运算的包
import numpy as np

# matplotlib.pyplot 是专门用于画图的包
import matplotlib.pyplot as plt

# 起点为0，终点为1(不包括1)，步长为0.01生成数组
x = np.arange(start = 0, stop = 1, step = 0.01)


# P(\theta|data) = \frac{P(data|\theta)*P(\theta)}{P(data)} 
y_posterior = (y_prior*y_likelihood)/np.sum(y_prior*y_likelihood)

# 画折线图
plt.plot(x,y_posterior)


# 添加标题
plt.title("Posterior")

# 添加y轴标签
plt.ylabel("probability density")

# %% [markdown]
# 若我们刻意改变旋转地球仪后手指指向陆地的先验概率，使手指指向陆地的概率在0.3以下特别低，超过0.3的话越接近1的概率越低

# %%
# numpy 是专门用于数组运算的包
import numpy as np

# 从scipy.stats里输入正态分布的函数
from scipy.stats import norm

# matplotlib.pyplot 是专门用于画图的包
import matplotlib.pyplot as plt



# 起点为0，终点为1(不包括1)，步长为0.01生成数组
x = np.arange(start = 0, stop = 1, step = 0.01)

# 正态分布的概率密度函数,x为变量，0.5为平均值，0.1为标准差
y_prior = np.concatenate([np.exp(np.linspace(0,0,30)),np.exp(np.linspace(1,0.3,70))])/np.sum(np.concatenate([np.exp(np.linspace(0,0,30)),np.exp(np.linspace(1,0.3,70))]))

# 画折线图
plt.plot(x,y_prior)

# 添加标题
plt.title("Prior")

# 添加y轴标签
plt.ylabel("probability")

# %%
# numpy 是专门用于数组运算的包
import numpy as np

# matplotlib.pyplot 是专门用于画图的包
import matplotlib.pyplot as plt


# 起点为0，终点为1(不包括1)，步长为0.01生成数组
x = np.arange(start = 0, stop = 1, step = 0.01)

# comb这个函数是专门用来算组合数的
from scipy.special import comb

theta = x

#  $\operatorname{Pr}(Z = 3\mid \theta) = \binom{10}{3} \theta^{3}(1-\theta)^{10-3}$
y_likelihood = comb(10,3)*((theta)**(3))*((1-theta)**(10-3))
# 画条形图
plt.plot(x,y_likelihood)

# 添加标题
plt.title("Likelihood")

# 添加y轴标签
plt.ylabel("likelihood")

# %%
# numpy 是专门用于数组运算的包
import numpy as np

# matplotlib.pyplot 是专门用于画图的包
import matplotlib.pyplot as plt

# 起点为0，终点为1(不包括1)，步长为0.01生成数组
x = np.arange(start = 0, stop = 1, step = 0.01)


# P(\theta|data) = \frac{P(data|\theta)*P(\theta)}{P(data)} 
y_posterior = (y_prior*y_likelihood)/np.sum(y_prior*y_likelihood)

# 画折线图
plt.plot(x,y_posterior)


# 添加标题
plt.title("Posterior")

# 添加y轴标签
plt.ylabel("probability density")

# %% [markdown]
# ## 先验是什么？代表了什么意义？

# %% [markdown]
# 先验的定义：先验（A priori）在拉丁文中指“在经验之前”，即无需经验或先于经验获得的知识。也就是还没有获得数据时我们对研究问题的看法。
#
# 要理解先验，需要与概念“后验”相结合。相对于“先验”，后验指在观察到现象或获得知识经验后对问题的看法。因此，后验是在观测到事件后对先验的更新。

# %% [markdown]
# 先验概率的定义：面对一件未发生的事情，对其将要发生的概率或者信念。这很好理解，在知道什么是先验后，只需要通过概率的语言来表达它就可以了。
#
# 同理，后验概率指在观测到一些事件与现象发生后，我们对一件未发生的事情将要发生的信念。
